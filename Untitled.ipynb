# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
student =  pd.read_csv('students.csv')

student
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             0     GP   F   18       U     GT3       A     4     4   at_home
# 1             1     GP   F   17       U     GT3       T     1     1   at_home
# 2             2     GP   F   15       U     LE3       T     1     1   at_home
# 3             3     GP   F   15       U     GT3       T     4     2    health
# 4             4     GP   F   16       U     GT3       T     3     3     other
# 5             5     GP   M   16       U     LE3       T     4     3  services
# 6             6     GP   M   16       U     LE3       T     2     2     other
# 7             7     GP   F   17       U     GT3       A     4     4     other
# 8             8    NaN   M   15       U     LE3       A     3     2       NaN
# 9             9     GP   M   15       U     GT3       T     3     4     other
# 10           10     GP   F   15       U     GT3       T     4     4   teacher
# 11           11     GP   F   15       U     GT3       T     2     1  services
# 12           12     GP   M   15       U     LE3       T     4     4    health
# 13           13     GP   M   15       U     GT3       T     4     3   teacher
# 14           14     GP   M   15       U     GT3       A     2     2     other
# 15           15     GP   F   16       U     GT3       T     4     4    health
# 16           16     GP   F   16       U     GT3       T     4     4  services
# 17           17     GP   F   16       U     GT3       T     3     3     other
# 18           18     GP   M   17       U     GT3       T     3     2  services
# 19           19     GP   M   16       U     LE3       T     4     3       NaN
# 20           20     GP   M   15       U     GT3       T     4     3       NaN
# 21           21     GP   M   15       U     GT3       T     4     4       NaN
# 22           22     GP   M   16       U     LE3       T     4     2   teacher
# 23           23     GP   M   16       U     LE3       T     2     2     other
# 24           24     GP   F   15       R     GT3       T     2     4  services
# 25           25     GP   F   16       U     GT3       T     2     2  services
# 26           26     GP   M   15       U     GT3       T     2     2     other
# 27           27     GP   M   15       U     GT3       T     4     2    health
# 28           28     GP   M   16       U     LE3       A     3     4  services
# 29           29     GP   M   16       U     GT3       T     4     4   teacher
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 365         365     MS   M   18       R     GT3       T     1     3   at_home
# 366         366     MS   M   18       U     LE3       T     4     4   teacher
# 367         367     MS   F   17       R     GT3       T     1     1     other
# 368         368     MS   F   18       U     GT3       T     2     3   at_home
# 369         369     MS   F   18       R     GT3       T     4     4     other
# 370         370     MS   F   19       U     LE3       T     3     2  services
# 371         371     MS   M   18       R     LE3       T     1     2       NaN
# 372         372     MS   F   17       U     GT3       T     2     2       NaN
# 373         373     MS   F   17       R     GT3       T     1     2     other
# 374         374     MS   F   18       R     LE3       T     4     4     other
# 375         375     MS   F   18       R     GT3       T     1     1     other
# 376         376     MS   F   20       U     GT3       T     4     2    health
# 377         377     MS   F   18       R     LE3       T     4     4   teacher
# 378         378     MS   F   18       U     GT3       T     3     3     other
# 379         379     MS   F   17       R     GT3       T     3     1   at_home
# 380         380     MS   M   18       U     GT3       T     4     4   teacher
# 381         381     MS   M   18       R     GT3       T     2     1     other
# 382         382     MS   M   17       U     GT3       T     2     3     other
# 383         383     MS   M   19       R     GT3       T     1     1     other
# 384         384     MS   M   18       R     GT3       T     4     2     other
# 385         385     MS   F   18       R     GT3       T     2     2   at_home
# 386         386     MS   F   18       R     GT3       T     4     4   teacher
# 387         387     MS   F   19       R     GT3       T     2     3  services
# 388         388     MS   F   18       U     LE3       T     3     1   teacher
# 389         389     MS   F   18       U     GT3       T     1     1       NaN
# 390         390     MS   M   20       U     LE3       A     2     2       NaN
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
#     ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0   ...      4        3     4     1     1       3        6   5   6   6
# 1   ...      5        3     3     1     1       3        4   5   5   6
# 2   ...      4        3     2     2     3       3       10   7   8  10
# 3   ...      3        2     2     1     1       5        2  15  14  15
# 4   ...      4        3     2     1     2       5        4   6  10  10
# 5   ...      5        4     2     1     2       5       10  15  15  15
# 6   ...      4        4     4     1     1       3        0  12  12  11
# 7   ...      4        1     4     1     1       1        6   6   5   6
# 8   ...      4        2     2     1     1       1        0  16  18  19
# 9   ...      5        5     1     1     1       5        0  14  15  15
# 10  ...      3        3     3     1     2       2        0  10   8   9
# 11  ...      5        2     2     1     1       4        4  10  12  12
# 12  ...      4        3     3     1     3       5        2  14  14  14
# 13  ...      5        4     3     1     2       3        2  10  10  11
# 14  ...      4        5     2     1     1       3        0  14  16  16
# 15  ...      4        4     4     1     2       2        4  14  14  14
# 16  ...      3        2     3     1     2       2        6  13  14  14
# 17  ...      5        3     2     1     1       4        4   8  10  10
# 18  ...      5        5     5     2     4       5       16   6   5   5
# 19  ...      3        1     3     1     3       5        4   8  10  10
# 20  ...      4        4     1     1     1       1        0  13  14  15
# 21  ...      5        4     2     1     1       5        0  12  15  15
# 22  ...      4        5     1     1     3       5        2  15  15  16
# 23  ...      5        4     4     2     4       5        0  13  13  12
# 24  ...      4        3     2     1     1       5        2  10   9   8
# 25  ...      1        2     2     1     3       5       14   6   9   8
# 26  ...      4        2     2     1     2       5        2  12  12  11
# 27  ...      2        2     4     2     4       1        4  15  16  15
# 28  ...      5        3     3     1     1       5        4  11  11  11
# 29  ...      4        4     5     5     5       5       16  10  12  11
# ..  ...    ...      ...   ...   ...   ...     ...      ...  ..  ..  ..
# 365 ...      3        3     4     2     4       3        4  10  10  10
# 366 ...      4        2     2     2     2       5        0  13  13  13
# 367 ...      5        2     1     1     2       1        0   7   6   0
# 368 ...      5        2     3     1     2       4        0  11  10  10
# 369 ...      3        2     2     4     2       5       10  14  12  11
# 370 ...      3        2     2     1     1       3        4   7   7   9
# 371 ...      4        3     3     2     3       3        3  14  12  12
# 372 ...      3        4     3     1     1       3        8  13  11  11
# 373 ...      3        5     5     1     3       1       14   6   5   5
# 374 ...      5        4     4     1     1       1        0  19  18  19
# 375 ...      4        3     2     1     2       4        2   8   8  10
# 376 ...      5        4     3     1     1       3        4  15  14  15
# 377 ...      5        4     3     3     4       2        4   8   9  10
# 378 ...      4        1     3     1     2       1        0  15  15  15
# 379 ...      4        5     4     2     3       1       17  10  10  10
# 380 ...      3        2     4     1     4       2        4  15  14  14
# 381 ...      4        4     3     1     3       5        5   7   6   7
# 382 ...      4        4     3     1     1       3        2  11  11  10
# 383 ...      4        3     2     1     3       5        0   6   5   0
# 384 ...      5        4     3     4     3       3       14   6   5   5
# 385 ...      5        3     3     1     3       4        2  10   9  10
# 386 ...      4        4     3     2     2       5        7   6   5   6
# 387 ...      5        4     2     1     2       5        0   7   5   0
# 388 ...      4        3     4     1     1       1        0   7   9   8
# 389 ...      1        1     1     1     1       5        0   6   5   0
# 390 ...      5        5     4     4     5       4       11   9   9   9
# 391 ...      2        4     5     3     4       2        3  14  16  16
# 392 ...      5        5     3     3     3       3        3  10   8   7
# 393 ...      4        4     1     3     4       5        0  11  12  10
# 394 ...      3        2     3     3     3       5        5   8   9   9
#
# [395 rows x 34 columns]

# %%
student.isna().sum()
# Out:
# Unnamed: 0     0
# school         4
# sex            0
# age            0
# address        0
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob          52
# Fjob          50
# reason         0
# guardian      14
# traveltime    58
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       0
# G1             0
# G2             0
# G3             0
# dtype: int64

# %%
student.internet[student['internet']=='yes'] = 1
student.internet[student['internet']=='no'] = 0
# Out:
# c:\users\clemence\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\clemence\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
student2 = sns.barplot(x="traveltime", y="G1", data=student)
# Out:
# c:\users\clemence\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
student.school[student['traveltime']==4]
# Out:
# 61     GP
# 108    GP
# 134    GP
# 149    GP
# 164    GP
# 228    GP
# 327    GP
# 375    MS
# Name: school, dtype: object

# %%
student3 = sns.barplot(x="traveltime", y="G2", data=student)

# %%
student4 = sns.barplot(x="traveltime", y="G3", data=student)

# %%
student4 = sns.boxplot(x='traveltime', y='G1', hue='school', data=student)

# %%
student4 = sns.boxplot(x='traveltime', y='G2', hue='school', data=student)

# %%
student4 = sns.boxplot(x='traveltime', y='G3', hue='school', data=student)

# %%
student5 = sns.boxplot(x='traveltime', y='G1', hue='studytime', data=student)

# %%
student.school[student['studytime']==4].value_counts()
# Out:
# GP    26
# Name: school, dtype: int64

# %%
student.school.value_counts()
# Out:
# GP    345
# MS     46
# Name: school, dtype: int64

# %%
student.studytime[student['traveltime']==4].value_counts()
# Out:
# 2    3
# 1    3
# 4    1
# 3    1
# Name: studytime, dtype: int64

# %%
col = ['res', 'type', 'trim']

a1 = student[(student.school == 'MS') & (student.studytime == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = student[(student.school == 'GP') & (student.studytime == 1)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = student[(student.school == 'MS') & (student.studytime == 2)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = student[(student.school == 'GP') & (student.studytime == 2)]
b4 = a4.loc[:,['G1','G2','G3']]

a5 = student[(student.school == 'MS') & (student.studytime == 3)]
b5 = a5.loc[:,['G1','G2','G3']]

a6 = student[(student.school == 'GP') & (student.studytime == 3)]
b6 = a6.loc[:,['G1','G2','G3']]

a7 = student[(student.school == 'MS') & (student.studytime == 4)]
b7 = a7.loc[:,['G1','G2','G3']]

a8 = student[(student.school == 'GP') & (student.studytime == 4)]
b8 = a8.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'MS studytime of 1',1],
    [b1.G2.mean(),'MS studytime of 1',2],
    [b1.G3.mean(),'MS studytime of 1',3],
    [b2.G1.mean(),'GP studytime of 1',1],
    [b2.G2.mean(),'GP studytime of 1',2],
    [b2.G3.mean(),'GP studytime of 1',3],
    [b3.G1.mean(),'MS studytime of 2',1],
    [b3.G2.mean(),'MS studytime of 2',2],
    [b3.G3.mean(),'MS studytime of 2',3],
    [b4.G1.mean(),'GP studytime of 2',1],
    [b4.G2.mean(),'GP studytime of 2',2],
    [b4.G3.mean(),'GP studytime of 2',3],
    [b5.G1.mean(),'MS studytime of 3',1],
    [b5.G2.mean(),'MS studytime of 3',2],
    [b5.G3.mean(),'MS studytime of 3',3],
    [b6.G1.mean(),'GP studytime of 3',1],
    [b6.G2.mean(),'GP studytime of 3',2],
    [b6.G3.mean(),'GP studytime of 3',3],
    [b7.G1.mean(),'MS studytime of 4',1],
    [b7.G2.mean(),'MS studytime of 4',2],
    [b7.G3.mean(),'MS studytime of 4',3],
    [b8.G1.mean(),'GP studytime of 4',1],
    [b8.G2.mean(),'GP studytime of 4',2],
    [b8.G3.mean(),'GP studytime of 4',3]],
    columns=col)
print(evo)
plt.subplots(figsize=(18,8))
sns.lineplot(x='trim',y='res',data=evo,hue="type")
# Out:
#           res               type  trim
# 0    8.937500  MS studytime of 1     1
# 1    8.562500  MS studytime of 1     2
# 2    7.875000  MS studytime of 1     3
# 3   10.670455  GP studytime of 1     1
# 4   10.579545  GP studytime of 1     2
# 5   10.409091  GP studytime of 1     3
# 6   11.136364  MS studytime of 2     1
# 7   10.818182  MS studytime of 2     2
# 8   10.590909  MS studytime of 2     3
# 9   10.545977  GP studytime of 2     1
# 10  10.419540  GP studytime of 2     2
# 11  10.068966  GP studytime of 2     3
# 12  12.875000  MS studytime of 3     1
# 13  11.750000  MS studytime of 3     2
# 14  11.750000  MS studytime of 3     3
# 15  11.929825  GP studytime of 3     1
# 16  11.473684  GP studytime of 3     2
# 17  11.350877  GP studytime of 3     3
# 18        NaN  MS studytime of 4     1
# 19        NaN  MS studytime of 4     2
# 20        NaN  MS studytime of 4     3
# 21  11.730769  GP studytime of 4     1
# 22  11.884615  GP studytime of 4     2
# 23  11.076923  GP studytime of 4     3

# %%
col = ['res', 'type', 'trim']

a1 = student[(student.traveltime == 1) & (student.studytime == 1)]
b1 = a1.loc[:,['G1','G2','G3']]

a2 = student[(student.traveltime == 2) & (student.studytime == 1)]
b2 = a2.loc[:,['G1','G2','G3']]

a3 = student[(student.traveltime == 3) & (student.studytime == 1)]
b3 = a3.loc[:,['G1','G2','G3']]

a4 = student[(student.traveltime == 4) & (student.studytime == 1)]
b4 = a4.loc[:,['G1','G2','G3']]

a5 = student[(student.traveltime == 1) & (student.studytime == 2)]
b5 = a5.loc[:,['G1','G2','G3']]

a6 = student[(student.traveltime == 2) & (student.studytime == 2)]
b6 = a3.loc[:,['G1','G2','G3']]

a7 = student[(student.traveltime == 3) & (student.studytime == 2)]
b7 = a7.loc[:,['G1','G2','G3']]

a8 = student[(student.traveltime == 4) & (student.studytime == 2)]
b8 = a8.loc[:,['G1','G2','G3']]
           
a9 = student[(student.traveltime == 1) & (student.studytime == 3)]
b9 = a9.loc[:,['G1','G2','G3']]

a10 = student[(student.traveltime == 2) & (student.studytime == 3)]
b10 = a10.loc[:,['G1','G2','G3']]

a11 = student[(student.traveltime == 3) & (student.studytime == 3)]
b11 = a11.loc[:,['G1','G2','G3']]

a12 = student[(student.traveltime == 4) & (student.studytime == 3)]
b12 = a12.loc[:,['G1','G2','G3']]
           
a13 = student[(student.traveltime == 1) & (student.studytime == 4)]
b13 = a13.loc[:,['G1','G2','G3']]

a14 = student[(student.traveltime == 2) & (student.studytime == 4)]
b14 = a14.loc[:,['G1','G2','G3']]

a15 = student[(student.traveltime == 3) & (student.studytime == 4)]
b15 = a15.loc[:,['G1','G2','G3']]

a16 = student[(student.traveltime == 4) & (student.studytime == 4)]
b16 = a16.loc[:,['G1','G2','G3']]

evo = pd.DataFrame([
    [b1.G1.mean(),'travel time of 1 studytime of 1',1],
    [b1.G2.mean(),'travel time of 1 studytime of 1',2],
    [b1.G3.mean(),'travel time of 1 studytime of 1',3],
    [b2.G1.mean(),'travel time of 2 studytime of 1',1],
    [b2.G2.mean(),'travel time of 2 studytime of 1',2],
    [b2.G3.mean(),'travel time of 2 studytime of 1',3],
    [b3.G1.mean(),'travel time of 3 studytime of 1',1],
    [b3.G2.mean(),'travel time of 3 studytime of 1',2],
    [b3.G3.mean(),'travel time of 3 studytime of 1',3],
    [b4.G1.mean(),'travel time of 4 studytime of 1',1],
    [b4.G2.mean(),'travel time of 4 studytime of 1',2],
    [b4.G3.mean(),'travel time of 4 studytime of 1',3],
    [b13.G1.mean(),'travel time of 1 studytime of 4',1],
    [b13.G2.mean(),'travel time of 1 studytime of 4',2],
    [b13.G3.mean(),'travel time of 1 studytime of 4',3],
    [b14.G1.mean(),'travel time of 2 studytime of 4',1],
    [b14.G2.mean(),'travel time of 2 studytime of 4',2],
    [b14.G3.mean(),'travel time of 2 studytime of 4',3],
    [b15.G1.mean(),'travel time of 3 studytime of 4',1],
    [b15.G2.mean(),'travel time of 3 studytime of 4',2],
    [b15.G3.mean(),'travel time of 3 studytime of 4',3],
    [b16.G1.mean(),'travel time of 4 studytime of 4',1],
    [b16.G2.mean(),'travel time of 4 studytime of 4',2],
    [b16.G3.mean(),'travel time of 4 studytime of 4',3]],
    columns=col)
print(evo)
plt.subplots(figsize=(18,8))
sns.lineplot(x='trim',y='res',data=evo,hue="type")
# Out:
#           res                             type  trim
# 0   10.716981  travel time of 1 studytime of 1     1
# 1   10.622642  travel time of 1 studytime of 1     2
# 2   10.452830  travel time of 1 studytime of 1     3
# 3    9.720000  travel time of 2 studytime of 1     1
# 4    9.680000  travel time of 2 studytime of 1     2
# 5    9.360000  travel time of 2 studytime of 1     3
# 6   10.500000  travel time of 3 studytime of 1     1
# 7    9.125000  travel time of 3 studytime of 1     2
# 8    7.625000  travel time of 3 studytime of 1     3
# 9    9.666667  travel time of 4 studytime of 1     1
# 10   9.000000  travel time of 4 studytime of 1     2
# 11  10.333333  travel time of 4 studytime of 1     3
# 12  11.916667  travel time of 1 studytime of 4     1
# 13  11.750000  travel time of 1 studytime of 4     2
# 14  12.166667  travel time of 1 studytime of 4     3
# 15  12.428571  travel time of 2 studytime of 4     1
# 16  12.857143  travel time of 2 studytime of 4     2
# 17  10.142857  travel time of 2 studytime of 4     3
# 18        NaN  travel time of 3 studytime of 4     1
# 19        NaN  travel time of 3 studytime of 4     2
# 20        NaN  travel time of 3 studytime of 4     3
# 21  10.000000  travel time of 4 studytime of 4     1
# 22  13.000000  travel time of 4 studytime of 4     2
# 23  13.000000  travel time of 4 studytime of 4     3

# %%
plt.subplots(figsize=(18,8))
student.absences.value_counts().plot.bar()

# %%
plt.subplots(figsize=(18,8))
student9 = sns.barplot(x='absences', y='G3', data=student)
